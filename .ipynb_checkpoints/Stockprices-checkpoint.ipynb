# %% [markdown]
# https://pythonprogramming.net/getting-stock-prices-python-programming-for-finance/

# %%
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib import style
import seaborn as sns
import pandas as pd
import pandas_datareader.data as web
from plotly import graph_objs as go
import requests

# %%
style.use('ggplot')

# %%
ticker0 = 'SPCE'
ticker1 = 'MRNA'
ticker2 = 'GILD'
ticker3 = 'TSLA'
ticker4 = 'AMD'
ticker5 = 'INTC'

nasdaq = 'NDAQ'
spy = 'SPY'

start = dt.datetime(2015,1,1)
end = dt.datetime.now()

# %%
df0 = web.DataReader(ticker0,"yahoo",start,end)
df1 = web.DataReader(ticker1,"yahoo",start,end)
df2 = web.DataReader(ticker2,"yahoo",start,end)
df3 = web.DataReader(ticker3,"yahoo",start,end)
df4 = web.DataReader(ticker4,"yahoo",start,end)
df5 = web.DataReader(ticker5,"yahoo",start,end)

dfnasdaq = web.DataReader(nasdaq,"yahoo",start,end)
dfspy = web.DataReader(spy,"yahoo",start,end)

# %%
df0.head()
df1.head()
df2.head()
df3.head()
df4.head()
df5.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2015-01-02  37.160000  36.110001  36.669998  36.360001  23605600.0  31.082489
# 2015-01-05  36.450001  35.939999  36.200001  35.950001  32785000.0  30.732008
# 2015-01-06  36.230000  35.259998  36.080002  35.279999  30847600.0  30.159252
# 2015-01-07  36.070000  35.270000  35.639999  36.020000  27725200.0  30.791851
# 2015-01-08  37.000000  36.259998  36.369999  36.689999  31765400.0  31.364601

# %%
df0.reset_index(inplace = True)
df1.reset_index(inplace = True)
df2.reset_index(inplace = True)
df3.reset_index(inplace = True)
df4.reset_index(inplace = True)
df5.reset_index(inplace = True)

df0.set_index("Date", inplace = True)
df1.set_index("Date", inplace = True)
df2.set_index("Date", inplace = True)
df3.set_index("Date", inplace = True)
df4.set_index("Date", inplace = True)
df5.set_index("Date", inplace = True)

# %%
#print(df0.head())
#print(df1.head())
#print(df2.head())
#print(df3.head())
#print(df4.head())
#print(df5.head())

# %%
df0['Adj Close'].plot(figsize=(20,20))
plt.title(ticker0)
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
def setplt(x = 13, y = 9, a = 1, b = 1):
    f, ax = plt.subplots(a,b,figsize = (x,y))
    sns.despine(f, left = True, bottom = True)
    return f, ax

# %%
f , ax = setplt(30,20,2,3)

#plotting
v_plot = df0['Adj Close'].plot( title = ticker0, ax = ax[0][0])
v_plot = df1['Adj Close'].plot( title = ticker1 ,ax = ax[0][1])
v_plot = df2['Adj Close'].plot( title = ticker2 ,ax = ax[0][2])
v_plot = df3['Adj Close'].plot( title = ticker3 ,ax = ax[1][0])
v_plot = df4['Adj Close'].plot( title = ticker4 ,ax = ax[1][1])
v_plot = df5['Adj Close'].plot( title = ticker5 ,ax = ax[1][2])

# %%
plt.rcParams['figure.figsize'] = (20,10)
ax3 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
ax4 = plt.subplot2grid((6,1), (5,0), rowspan=1, colspan=1,sharex=ax3)

df0['100ma'] = df0['Adj Close'].rolling(window = 10).mean()

ax3.plot(df0['Adj Close'])
ax3.plot(df0['100ma'])
ax4.bar(df0.index,df0['Volume'])
# Out:
# <BarContainer object of 414 artists>

# %%
def hundredavevol(df,ttl,ave):
    plt.rcParams['figure.figsize'] = (20,10)
    ax3 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
    ax4 = plt.subplot2grid((6,1), (5,0), rowspan=1, colspan=1,sharex=ax3)

    df['100ma'] = df['Adj Close'].rolling(window = ave).mean()
    
    ax3.title.set_text(ttl)
    ax3.plot(df['Adj Close'])
    ax3.plot(df['100ma'])
    ax4.bar(df.index,df['Volume'])

# %%
hundredavevol(df0,ticker0,20)

# %%
hundredavevol(df1,ticker1,20)

# %%
hundredavevol(df2,ticker2,20)

# %%
hundredavevol(df3,ticker3,20)

# %%
hundredavevol(df4,ticker4,20)

# %%
hundredavevol(df5,ticker5,20)

# %%
hundredavevol(dfnasdaq,nasdaq,20)

# %%
hundredavevol(dfspy,spy,20)

# %%
df0.head()
# Out:
#              High    Low    Open  Close   Volume  Adj Close  100ma
# Date
# 2019-03-11  10.16  10.12  10.120  10.14    93300      10.14    NaN
# 2019-03-12  10.15  10.13  10.150  10.14  1318200      10.14    NaN
# 2019-03-13  10.14  10.14  10.140  10.14     5000      10.14    NaN
# 2019-03-14  10.15  10.14  10.144  10.14   176800      10.14    NaN
# 2019-03-15  10.14  10.13  10.130  10.13   158300      10.13    NaN

# %%
df0_ohlc = df0.drop(columns = ['Adj Close','100ma'])
df1_ohlc = df1.drop(columns = ['Adj Close','100ma'])
df2_ohlc = df2.drop(columns = ['Adj Close','100ma'])
df3_ohlc = df3.drop(columns = ['Adj Close','100ma'])
df4_ohlc = df4.drop(columns = ['Adj Close','100ma'])
df5_ohlc = df5.drop(columns = ['Adj Close','100ma'])

# %%
df0_ohlc.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume'], dtype='object')

# %%
df0_ohlc.reset_index(inplace = True)
df1_ohlc.reset_index(inplace = True)
df2_ohlc.reset_index(inplace = True)
df3_ohlc.reset_index(inplace = True)
df4_ohlc.reset_index(inplace = True)
df5_ohlc.reset_index(inplace = True)

df0_ohlc.set_index("Date", inplace = False)
df1_ohlc.set_index("Date", inplace = False)
df2_ohlc.set_index("Date", inplace = False)
df3_ohlc.set_index("Date", inplace = False)
df4_ohlc.set_index("Date", inplace = False)
df5_ohlc.set_index("Date", inplace = False)
# Out:
#                  High        Low       Open      Close      Volume
# Date
# 2015-01-02  37.160000  36.110001  36.669998  36.360001  23605600.0
# 2015-01-05  36.450001  35.939999  36.200001  35.950001  32785000.0
# 2015-01-06  36.230000  35.259998  36.080002  35.279999  30847600.0
# 2015-01-07  36.070000  35.270000  35.639999  36.020000  27725200.0
# 2015-01-08  37.000000  36.259998  36.369999  36.689999  31765400.0
# ...               ...        ...        ...        ...         ...
# 2020-10-21  54.070000  52.820000  53.139999  53.500000  21866000.0
# 2020-10-22  54.220001  53.070000  53.119999  53.900002  41522700.0
# 2020-10-23  48.669998  47.660000  48.349998  48.200001  97322500.0
# 2020-10-26  47.860001  46.250000  47.849998  46.720001  53842800.0
# 2020-10-27  46.410000  45.360001  45.980000  45.639999  46079968.0
#
# [1466 rows x 5 columns]

# %%
def candlesticks(ohlc, tick):
    cs = go.Figure(data = [go.Candlestick( 
                    x = ohlc['Date'],
                    open = ohlc['Open'], 
                    high = ohlc['High'],
                    low = ohlc['Low'], 
                    close = ohlc['Close'])])
    cs.update_layout(title = tick)


    cs.show()

# %%
candlesticks(df2_ohlc, ticker2)
# Out:
# <div>                            <div id="9d9aec48-b7e6-462c-8759-13db7ef3f6e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d9aec48-b7e6-462c-8759-13db7ef3f6e0")) {                    Plotly.newPlot(                        "9d9aec48-b7e6-462c-8759-13db7ef3f6e0",                        [{"close": [94.91000366210938, 96.79000091552734, 97.6500015258789, 99.4800033569336, 102.30000305175781, 102.20999908447266, 101.20999908447266, 97.20999908447266, 99.26000213623047, 97.4000015258789, 100.70999908447266, 103.77999877929688, 103.58000183105469, 105.13999938964844, 105.54000091552734, 107.11000061035156, 105.02999877929688, 102.44999694824219, 104.18000030517578, 104.83000183105469, 106.19000244140625, 107.18000030517578, 98.43000030517578, 99.9000015258789, 97.4800033569336, 96.9000015258789, 98.31999969482422, 99.9800033569336, 100.80000305175781, 101.9000015258789, 103.83999633789062, 103.94000244140625, 102.7300033569336, 102.61000061035156, 104.51000213623047, 104.69999694824219, 104.43000030517578, 104.19000244140625, 103.52999877929688, 103.83000183105469, 102.79000091552734, 103.05999755859375, 103.41999816894531, 101.80999755859375, 101.37000274658203, 98.83000183105469, 98.97000122070312, 99.93000030517578, 99.61000061035156, 101.30000305175781, 100.44000244140625, 100.27999877929688, 101.44000244140625, 102.29000091552734, 100.26000213623047, 101.41000366210938, 99.86000061035156, 101.08000183105469, 101.0, 100.69000244140625, 98.12999725341797, 97.72000122070312, 98.43000030517578, 97.79000091552734, 98.69000244140625, 99.87000274658203, 101.16000366210938, 101.7699966430664, 102.27999877929688, 102.20999908447266, 104.02999877929688, 103.33999633789062, 101.37999725341797, 100.66000366210938, 105.19999694824219, 104.18000030517578, 105.20999908447266, 103.69999694824219, 102.94000244140625, 103.72000122070312, 102.31999969482422, 100.51000213623047, 105.01000213623047, 105.66000366210938, 102.98999786376953, 102.2699966430664, 101.79000091552734, 103.8499984741211, 104.7300033569336, 105.55999755859375, 106.38999938964844, 108.73999786376953, 109.30000305175781, 111.0, 110.55999755859375, 110.16999816894531, 111.22000122070312, 111.70999908447266, 109.7699966430664, 112.45999908447266, 112.8499984741211, 112.2699966430664, 114.08000183105469, 113.94000244140625, 114.6500015258789, 113.93000030517578, 113.95999908447266, 113.69999694824219, 114.75, 117.66999816894531, 119.12999725341797, 117.66000366210938, 118.16000366210938, 119.06999969482422, 118.87999725341797, 121.20999908447266, 119.80000305175781, 121.48999786376953, 122.20999908447266, 122.01000213623047, 120.2300033569336, 119.5, 115.45999908447266, 117.08000183105469, 116.01000213623047, 115.04000091552734, 115.66000366210938, 115.12999725341797, 112.94000244140625, 113.36000061035156, 113.73999786376953, 114.55000305175781, 117.36000061035156, 117.38999938964844, 118.8499984741211, 118.26000213623047, 118.19999694824219, 117.77999877929688, 117.44000244140625, 117.66000366210938, 112.83000183105469, 110.54000091552734, 113.06999969482422, 115.70999908447266, 117.9000015258789, 117.86000061035156, 119.5999984741211, 118.87000274658203, 118.66000366210938, 115.30000305175781, 114.44000244140625, 116.58000183105469, 115.61000061035156, 116.25, 115.19999694824219, 115.5999984741211, 116.41999816894531, 117.05999755859375, 116.20999908447266, 112.38999938964844, 105.33000183105469, 100.66000366210938, 102.55999755859375, 106.95999908447266, 107.98999786376953, 107.77999877929688, 105.06999969482422, 101.48999786376953, 104.2699966430664, 101.91000366210938, 102.05999755859375, 104.9000015258789, 103.81999969482422, 107.25, 109.62999725341797, 109.3499984741211, 111.05000305175781, 111.02999877929688, 111.61000061035156, 10 ...

# %%
dfnasdaq.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close  \
# Date
# 2015-01-02  48.410000  47.419998  48.220001  47.860001   596100.0  43.035145
# 2015-01-05  47.910000  47.259998  47.619999  47.610001   955600.0  42.810345
# 2015-01-06  47.980000  47.160000  47.759998  47.580002  1034700.0  42.783375
# 2015-01-07  48.279999  47.320000  47.889999  48.259998   990800.0  43.394821
# 2015-01-08  49.330002  48.439999  48.490002  49.009998  1205600.0  44.069218
#
#             100ma
# Date
# 2015-01-02    NaN
# 2015-01-05    NaN
# 2015-01-06    NaN
# 2015-01-07    NaN
# 2015-01-08    NaN

# %%
"""
plt.plot(df0['Adj Close']+92)
plt.plot(df5['Adj Close']+47)
plt.plot(dfnasdaq['Adj Close'])
"""
# Out:
# "\nplt.plot(df0['Adj Close']+92)\nplt.plot(df5['Adj Close']+47)\nplt.plot(dfnasdaq['Adj Close'])\n"

# %% [markdown]
# **The Machine Learning Part**

# %%
plt.plot(df2['Adj Close'])

# %%
#Is pytorch working?
from __future__ import print_function
import torch
x = torch.rand(5, 3)
print(x, "\nyes it is working.")
# Out:
# tensor([[0.2966, 0.5784, 0.3789],
#         [0.7251, 0.2272, 0.8922],
#         [0.9851, 0.5509, 0.7177],
#         [0.4463, 0.2750, 0.8720],
#         [0.7123, 0.8354, 0.4283]])
# yes it is working.

# %%
from sklearn.preprocessing import MinMaxScaler

#Normalizing data
price = df2[['Adj Close']]
scaler = MinMaxScaler(feature_range=(-1,1))
price['Adj Close'] = scaler.fit_transform(price['Adj Close'].values.reshape(-1,1))
# Out:
# <ipython-input-85-d4c9ed5ba4db>:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def split_data(stock, lookback):
    data_raw = stock.to_numpy()
    data = []
    
    for index in range(len(data_raw) - lookback):
        data.append(data_raw[index: index + lookback])
    
    data = np.array(data);
    test_set_size = int(np.round(0.2*data.shape[0]));
    train_set_size = data.shape[0] - (test_set_size);
    
    x_train = data[:train_set_size,:-1,:]
    y_train = data[:train_set_size,-1,:]
    
    x_test = data[train_set_size:,:-1]
    y_test = data[train_set_size,-1,:]
    
    return [x_train, y_train, x_test, y_test]

lookback = 20 #choosing sequence length
x_train, y_train, x_test, y_test = split_data(price, lookback)

# %%
#transform to tensors for pytorch

import torch
import torch.nn as nn


x_train = torch.from_numpy(x_train).type(torch.Tensor)
x_test = torch.from_numpy(x_test).type(torch.Tensor)
y_train_lstm = torch.from_numpy(y_train).type(torch.Tensor)
y_test_lstm = torch.from_numpy(y_test).type(torch.Tensor)
y_train_gru = torch.from_numpy(y_train).type(torch.Tensor)
y_test_gru = torch.from_numpy(y_test).type(torch.Tensor)

# %%
#model inputs
input_dim = 1
hidden_dim = 32
num_layers = 2
output_dim = 1
num_epochs = 100

# %%
class LSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super(LSTM, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_()
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_()
        out, (hn, cn) = self.lstm(x, (h0.detach(), c0.detach()))
        out = self.fc(out[:, -1, :]) 
        return out

# %%
model = LSTM(input_dim=input_dim, hidden_dim=hidden_dim, output_dim=output_dim, num_layers=num_layers)
criterion = torch.nn.MSELoss(reduction='mean')
optimiser = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
import time
hist = np.zeros(num_epochs)
start_time = time.time()
lstm = []
for t in range(num_epochs):
    y_train_pred = model(x_train)
    loss = criterion(y_train_pred, y_train_lstm)
    print("Epoch ", t, "MSE: ", loss.item())
    hist[t] = loss.item()
    optimiser.zero_grad()
    loss.backward()
    optimiser.step()
    
training_time = time.time()-start_time
print("Training time: {}".format(training_time))
# Out:
# Epoch  0 MSE:  0.24419836699962616
# Epoch  1 MSE:  0.210990771651268
# Epoch  2 MSE:  0.1993914395570755
# Epoch  3 MSE:  0.1716504544019699
# Epoch  4 MSE:  0.12339190393686295
# Epoch  5 MSE:  0.06660738587379456
# Epoch  6 MSE:  0.036089926958084106
# Epoch  7 MSE:  0.08241048455238342
# Epoch  8 MSE:  0.04352150112390518
# Epoch  9 MSE:  0.021441055461764336
# Epoch  10 MSE:  0.01777089573442936
# Epoch  11 MSE:  0.025517644360661507
# Epoch  12 MSE:  0.029045285657048225
# Epoch  13 MSE:  0.026758261024951935
# Epoch  14 MSE:  0.02173980511724949
# Epoch  15 MSE:  0.016930539160966873
# Epoch  16 MSE:  0.014263154938817024
# Epoch  17 MSE:  0.015540922060608864
# Epoch  18 MSE:  0.019143791869282722
# Epoch  19 MSE:  0.01852715201675892
# Epoch  20 MSE:  0.014572704210877419
# Epoch  21 MSE:  0.01188188698142767
# Epoch  22 MSE:  0.011043750680983067
# Epoch  23 MSE:  0.011055796407163143
# Epoch  24 MSE:  0.011480365879833698
# Epoch  25 MSE:  0.011792046017944813
# Epoch  26 MSE:  0.01110106147825718
# Epoch  27 MSE:  0.009547603316605091
# Epoch  28 MSE:  0.008512136526405811
# Epoch  29 MSE:  0.008559095673263073
# Epoch  30 MSE:  0.008850572630763054
# Epoch  31 MSE:  0.008915772661566734
# Epoch  32 MSE:  0.009220089763402939
# Epoch  33 MSE:  0.009436908178031445
# Epoch  34 MSE:  0.008732105605304241
# Epoch  35 MSE:  0.007843753322958946
# Epoch  36 MSE:  0.007551092654466629
# Epoch  37 MSE:  0.007439812645316124
# Epoch  38 MSE:  0.00726371118798852
# Epoch  39 MSE:  0.007288304623216391
# Epoch  40 MSE:  0.007391378283500671
# Epoch  41 MSE:  0.007142251823097467
# Epoch  42 MSE:  0.006669791880995035
# Epoch  43 MSE:  0.006381395738571882
# Epoch  44 MSE:  0.006276899948716164
# Epoch  45 MSE:  0.0062106335535645485
# Epoch  46 MSE:  0.006244286894798279
# Epoch  47 MSE:  0.006341646425426006
# Epoch  48 MSE:  0.0062429215759038925
# Epoch  49 MSE:  0.005965775810182095
# Epoch  50 MSE:  0.00579987233504653
# Epoch  51 MSE:  0.005785895977169275
# Epoch  52 MSE:  0.005774462595582008
# Epoch  53 MSE:  0.00574537692591548
# Epoch  54 MSE:  0.005712862126529217
# Epoch  55 MSE:  0.005594072863459587
# Epoch  56 MSE:  0.00541881425306201
# Epoch  57 MSE:  0.005337190348654985
# Epoch  58 MSE:  0.005336025729775429
# Epoch  59 MSE:  0.00531261321157217
# Epoch  60 MSE:  0.0052769361063838005
# Epoch  61 MSE:  0.005225420463830233
# Epoch  62 MSE:  0.005127291195094585
# Epoch  63 MSE:  0.005064996890723705
# Epoch  64 MSE:  0.005063927266746759
# Epoch  65 MSE:  0.005047814920544624
# Epoch  66 MSE:  0.005016125272959471
# Epoch  67 MSE:  0.004978507291525602
# Epoch  68 MSE:  0.004910764750093222
# Epoch  69 MSE:  0.004860760644078255
# Epoch  70 MSE:  0.004846011288464069
# Epoch  71 MSE:  0.004821256268769503
# Epoch  72 MSE:  0.004791001323610544
# Epoch  73 MSE:  0.004753760062158108
# Epoch  74 MSE:  0.004703950136899948
# Epoch  75 MSE:  0.004677032120525837
# Epoch  76 MSE:  0.00466284342110157
# Epoch  77 MSE:  0.004639159422367811
# Epoch  78 MSE:  0.00461456086486578
# Epoch  79 MSE:  0.004581126384437084
# Epoch  80 MSE:  0.004549289587885141
# Epoch  81 MSE:  0.004532736726105213
# Epoch  82 MSE:  0.004512862768024206
# Epoch  83 MSE:  0.004488823469728231
# Epoch  84 MSE:  0.0044621918350458145
# Epoch  85 MSE:  0.004432540852576494
# Epoch  86 MSE:  0.004412542562931776
# Epoch  87 MSE:  0.0043937345035374165
# Epoch  88 MSE:  0.004371010698378086
# Epoch  89 MSE:  0.00434791948646307
# Epoch  90 MSE:  0.00432245060801506
# Epoch  91 MSE:  0.004302352666854858
# Epoch  92 MSE:  0.004284163471311331
# Epoch  93 MSE:  0.0042630755342543125
# Epoch  94 MSE:  0.004241699352860451
# Epoch  95 MSE:  0.0042186519131064415
# Epoch  96 MSE:  0.004198687616735697
# Epoch  97 MSE:  0.00417978223413229
# Epoch  98 MSE:  0.004159046337008476
# Epoch  99 MSE:  0.004138134885579348
# Training time: 16.835716009140015

# %%
predict = pd.DataFrame(scaler.inverse_transform(y_train_pred.detach().numpy()))
original = pd.DataFrame(scaler.inverse_transform(y_train_lstm.detach().numpy()))

# %%
plt.plot(predict)
plt.plot(original)
